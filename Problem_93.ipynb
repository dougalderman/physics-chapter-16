# %%
#Problem 93

# %%
x=var('x')

# %%
#a

# %%
def f(x): return (2.0*sin((2*pi*x)/80))

# %%
plot(f(x),(x,0,160), fill=true, color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#b

# %%
def f2(x): return (2.0*sin(2*pi*(x/80 + 1/8)))

# %%
plot(f2(x),(x,0,160), fill=true, color='blue', legend_label='f2(x)')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#c

# %%
def f3(x): return (2.0*sin(2*pi*(x/80 + 1/4)))

# %%
plot(f3(x),(x,0,160), fill=true, color='blue', legend_label='f3(x)')
# Out:
# Graphics object consisting of 2 graphics primitives
